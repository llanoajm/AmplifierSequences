# %%
# Import the PeppercornRunner class
from peppercorn_runner import PeppercornRunner
from enumeration_plotter import EnumerationPlotter

# %%
runner = PeppercornRunner("shadow") # peppercorn -o <name>.pil --reject-remote --ignore-branch-4way --k-slow 1e-5 --k-fast 1e-1 -c  --complex-prefix EC <name>.pil

runner.run()
plotter = EnumerationPlotter()
plotter.plot()
with open("enum.pil", 'w'):
    pass
# Out:
# Command timed out.
# No content to display.

# %%
runner = PeppercornRunner("default") # > peppercorn -o enum.pil -c  -L 7 --ignore-branch-4way  main.pil
runner.run()
plotter = EnumerationPlotter()
plotter.plot()
with open("enum.pil", 'w'):
    pass
# Out:
# Command executed successfully.
